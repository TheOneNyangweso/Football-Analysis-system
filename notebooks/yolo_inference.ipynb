# %%
# To be commented out if colab is not used
# from google.colab import drive
# from pathlib import Path
# import os
# drive.mount('/content/drive')
# x = '/content/drive/MyDrive/Football-Analysis-System/'
# path = Path(x)
# os.listdir(path)

# %% [markdown]
# This is a colab related directory command...to be commented out if local
# machine is being used

# %%
# cd / content/drive/MyDrive/Football-Analysis-System

# %%
from ultralytics import YOLO

# %% [markdown]
# Higher yolo models such as yolov8l and yolov8x produce better results but putting my machine into consideration \
# I'll use yolov8m. But since Colab offers free gpu...that will be used for now

# %%
# Local base model
model = YOLO('yolov8m')
# Colab base model
# model = YOLO('yolov8x')

# %%
# local version
# result = model.predict(
#     '/home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4', save=True)

# colab version


print(result[0])
print('============================')
for box in result[0].boxes:
    print(box)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 23 persons, 1 sports ball, 1 tv, 2841.1ms
# video 1/1 (2/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 23 persons, 1 sports ball, 1 tv, 2577.8ms
# video 1/1 (3/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 24 persons, 1 tv, 1907.8ms
# video 1/1 (4/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 26 persons, 1 sports ball, 1 tv, 1954.0ms
# video 1/1 (5/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 24 persons, 1 sports ball, 1 tv, 1596.3ms
# video 1/1 (6/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 26 persons, 1 tv, 1558.4ms
# video 1/1 (7/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 25 persons, 1 tv, 2174.3ms
# video 1/1 (8/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 25 persons, 1 sports ball, 1 tv, 1687.4ms
# video 1/1 (9/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 25 persons, 1 sports ball, 1 tv, 2186.9ms
# video 1/1 (10/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 27 persons, 1 sports ball, 1 tv, 1897.7ms
# video 1/1 (11/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 26 persons, 1 tv, 2101.5ms
# video 1/1 (12/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 27 persons, 1 tv, 1710.9ms
# video 1/1 (13/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 25 persons, 1 tv, 1737.4ms
# video 1/1 (14/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 25 persons, 1 tv, 1565.8ms
# video 1/1 (15/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 25 persons, 1 sports ball, 1 tv, 1792.1ms
# video 1/1 (16/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 25 persons, 1 tv, 1551.5ms
# video 1/1 (17/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 25 persons, 1 tv, 1903.5ms
# video 1/1 (18/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 25 persons, 1 tv, 2313.0ms
# video 1/1 (19/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 26 persons, 1 sports ball, 1 tv, 1886.3ms
# video 1/1 (20/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 26 persons, 1 sports ball, 1 tv, 1589.1ms
# video 1/1 (21/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 25 persons, 1 tv, 1570.6ms
# video 1/1 (22/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 26 persons, 1 sports ball, 1 tv, 1811.8ms
# video 1/1 (23/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 26 persons, 1 sports ball, 1 tv, 1801.0ms
# video 1/1 (24/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 25 persons, 1 tv, 1586.0ms
# video 1/1 (25/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 25 persons, 1 sports ball, 1 tv, 1717.6ms
# video 1/1 (26/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 25 persons, 1 tv, 1611.2ms
# video 1/1 (27/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 25 persons, 1 tv, 1907.5ms
# video 1/1 (28/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 25 persons, 1 sports ball, 1 tv, 2355.7ms
# video 1/1 (29/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 25 persons, 1 sports ball, 1 tv, 2600.0ms
# video 1/1 (30/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 25 persons, 1 sports ball, 1 tv, 3120.7ms
# video 1/1 (31/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 25 persons, 1 sports ball, 1 tv, 3505.4ms
# video 1/1 (32/750) /home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4: 384x640 25 persons, 1 tv, 4686.1ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 result = model.predict(
#       2     '/home/nyangweso/Desktop/Projects/Football-Analysis-system/clips/08fd33_4.mp4', save=True)
#       4 print(result[0])
#       5 print('============================')
#
# File ~/miniconda3/envs/FastAPI/lib/python3.11/site-packages/ultralytics/engine/model.py:257, in Model.predict(self, source, stream, predictor, **kwargs)
#     255 if prompts and hasattr(self.predictor, 'set_prompts'):  # for SAM-type models
#     256     self.predictor.set_prompts(prompts)
# --> 257 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/miniconda3/envs/FastAPI/lib/python3.11/site-packages/ultralytics/engine/predictor.py:198, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     196     return self.stream_inference(source, model, *args, **kwargs)
#     197 else:
# --> 198     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/miniconda3/envs/FastAPI/lib/python3.11/site-packages/torch/utils/_contextlib.py:56, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      53         else:
#      54             # Pass the last request to the generator and get its response
#      55             with ctx_factory():
# ---> 56                 response = gen.send(request)
#      58 # We let the exceptions raised above by the generator's `.throw` or
#      59 # `.send` methods bubble up to our caller, except for StopIteration
#      60 except StopIteration as e:
#      61     # The generator informed us that it is done: take whatever its
#      62     # returned value (if any) was and indicate that we're done too
#      63     # by returning it (see docs for python's return-statement).
#
# File ~/miniconda3/envs/FastAPI/lib/python3.11/site-packages/ultralytics/engine/predictor.py:265, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     263 # Inference
#     264 with profilers[1]:
# --> 265     preds = self.inference(im, *args, **kwargs)
#     266     if self.args.embed:
#     267         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~/miniconda3/envs/FastAPI/lib/python3.11/site-packages/ultralytics/engine/predictor.py:137, in BasePredictor.inference(self, im, *args, **kwargs)
#     134 """Runs inference on a given image using the specified model and arguments."""
#     135 visualize = increment_path(self.save_dir / Path(self.batch[0][0]).stem,
#     136                            mkdir=True) if self.args.visualize and (not self.source_type.tensor) else False
# --> 137 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~/miniconda3/envs/FastAPI/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/FastAPI/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/FastAPI/lib/python3.11/site-packages/ultralytics/nn/autobackend.py:356, in AutoBackend.forward(self, im, augment, visualize, embed)
#     353     im = im.permute(0, 2, 3, 1)  # torch BCHW to numpy BHWC shape(1,320,192,3)
#     355 if self.pt or self.nn_module:  # PyTorch
# --> 356     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     357 elif self.jit:  # TorchScript
#     358     y = self.model(im)
#
# File ~/miniconda3/envs/FastAPI/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/FastAPI/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/FastAPI/lib/python3.11/site-packages/ultralytics/nn/tasks.py:42, in BaseModel.forward(self, x, *args, **kwargs)
#      40 if isinstance(x, dict):  # for cases of training and validating while training.
#      41     return self.loss(x, *args, **kwargs)
# ---> 42 return self.predict(x, *args, **kwargs)
#
# File ~/miniconda3/envs/FastAPI/lib/python3.11/site-packages/ultralytics/nn/tasks.py:60, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#      58 if augment:
#      59     return self._predict_augment(x)
# ---> 60 return self._predict_once(x, profile, visualize, embed)
#
# File ~/miniconda3/envs/FastAPI/lib/python3.11/site-packages/ultralytics/nn/tasks.py:81, in BaseModel._predict_once(self, x, profile, visualize, embed)
#      79 if profile:
#      80     self._profile_one_layer(m, x, dt)
# ---> 81 x = m(x)  # run
#      82 y.append(x if m.i in self.save else None)  # save output
#      83 if visualize:
#
# File ~/miniconda3/envs/FastAPI/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/FastAPI/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/FastAPI/lib/python3.11/site-packages/ultralytics/nn/modules/block.py:146, in SPPF.forward(self, x)
#     144 def forward(self, x):
#     145     """Forward pass through Ghost Convolution block."""
# --> 146     x = self.cv1(x)
#     147     y1 = self.m(x)
#     148     y2 = self.m(y1)
#
# File ~/miniconda3/envs/FastAPI/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/FastAPI/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/FastAPI/lib/python3.11/site-packages/ultralytics/nn/modules/conv.py:40, in Conv.forward_fuse(self, x)
#      38 def forward_fuse(self, x):
#      39     """Perform transposed convolution of 2D data."""
# ---> 40     return self.act(self.conv(x))
#
# File ~/miniconda3/envs/FastAPI/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/FastAPI/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/FastAPI/lib/python3.11/site-packages/torch/nn/modules/conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/miniconda3/envs/FastAPI/lib/python3.11/site-packages/torch/nn/modules/conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
